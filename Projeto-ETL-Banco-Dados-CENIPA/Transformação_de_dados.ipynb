# %%
#Importando bibliotecas
import pandas as pd
import pandera as pa

# %%
valores_ausentes=['**','*****','###!','NULL','####','****']
df = pd.read_csv('ocorrencia.csv',parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
schema = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia': pa.Column(pa.Int),
        'codigo_ocorrencia2': pa.Column(pa.Int),
        'ocorrencia_classificacao':pa.Column(pa.String),
        'ocorrencia_cidade':pa.Column(pa.String),
        'ocorrencia_uf':pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_aerodromo':pa.Column(pa.String, nullable=True),
        'ocorrencia_dia':pa.Column(pa.DateTime),
        'ocorrencia_hora': pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable=True),
        'total_recomendacoes':pa.Column(pa.Int)
    }

)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6088              80245               80245                INCIDENTE
# 6089              80247               80247                INCIDENTE
# 6090              80251               80251                INCIDENTE
# 6091              80257               80257                 ACIDENTE
# 6092              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia                         80259
# codigo_ocorrencia2                        80259
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                      CAMPINAS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBKP
# ocorrencia_dia              2021-08-18 00:00:00
# ocorrencia_hora                        12:45:00
# total_recomendacoes                           0
# Name: 6092, dtype: object

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6088              80245               80245                INCIDENTE
# 6089              80247               80247                INCIDENTE
# 6090              80251               80251                INCIDENTE
# 6091              80257               80257                 ACIDENTE
# 6092              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6088            RECIFE            PE                 SBRF     2021-08-15
# 6089       PORTO VELHO            RO                 SBPV     2021-08-16
# 6090             BELÉM            PA                 SBBE     2021-08-17
# 6091        DOM AQUINO            MT                  NaN     2021-08-18
# 6092          CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 6088        15:05:00                    0
# ...

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# ...

# %%
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# ...

# %%
df.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6088    PE
# 6089    RO
# 6090    PA
# 6091    MT
# 6092    SP
# Name: ocorrencia_uf, Length: 6093, dtype: object

# %%
#buscando os dados de uma coluna
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6088    PE
# 6089    RO
# 6090    PA
# 6091    MT
# 6092    SP
# Name: ocorrencia_uf, Length: 6093, dtype: object

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2445
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2445
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#podemo exibir as linhas não disponiveis
#df.loc[df.ocorrencia_uf.isnull()]
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5842              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5842      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0
# 5842        11:00:00                    0

# %%
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6071              80236               80236                 ACIDENTE
# 6072              80227               80227                 ACIDENTE
# 6075              80229               80229                INCIDENTE
# 6078              80233               80233                 ACIDENTE
# 6091              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro = df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4100              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4100           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4100             NaN                    0

# %%
df.count()
# Out:
# codigo_ocorrencia           6093
# codigo_ocorrencia2          6093
# ocorrencia_classificacao    6093
# ocorrencia_cidade           6093
# ocorrencia_uf               6091
# ocorrencia_aerodromo        3648
# ocorrencia_dia              6093
# ocorrencia_hora             6092
# total_recomendacoes         6093
# dtype: int64

# %%
#ocorrencias com mais de 10 recomendações
filtros= df.total_recomendacoes > 10
df.loc[filtros]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2797              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
#ocorrências com mais de 10 recomendações
filtros= df.total_recomendacoes > 10
df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
# ocorrência cuja classificação == INCIDENTE GRAVE
filtros= df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtros]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6069              80221               80221          INCIDENTE GRAVE
# 6074              80228               80228          INCIDENTE GRAVE
# 6076              80231               80231          INCIDENTE GRAVE
# 6077              80248               80248          INCIDENTE GRAVE
# 6083              80238               80238          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja classificação == INCIDENTE GRAVE e o estado  == sp
filtro1= df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2= df.ocorrencia_uf == 'SP'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5930              80056               80056          INCIDENTE GRAVE
# 5981              80114               80114          INCIDENTE GRAVE
# 5988              80124               80124          INCIDENTE GRAVE
# 6060              80200               80200          INCIDENTE GRAVE
# 6083              80238               80238          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja classificação == INCIDENTE GRAVE ou o estado  == sp
filtro1= df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2= df.ocorrencia_uf == 'SP'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 6076              80231               80231          INCIDENTE GRAVE
# 6077              80248               80248          INCIDENTE GRAVE
# 6083              80238               80238          INCIDENTE GRAVE
# 6087              80244               80244                INCIDENTE
# 6092              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja (classificação == INCIDENTE GRAVE ou classificação == INCIDENTE) e o estado  == sp
#filtro1= (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
#outra maneira de expressar isto é usando o metodo .isin que o mesmo
filtro1= df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE']) 
filtro2= df.ocorrencia_uf == 'SP'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 6063              80234               80234                INCIDENTE
# 6064              80208               80208                INCIDENTE
# 6083              80238               80238          INCIDENTE GRAVE
# 6087              80244               80244                INCIDENTE
# 6092              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja cidade comecen com a letra C
filtro= df.ocorrencia_cidade.str[0]=='C'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 6073              80225               80225                INCIDENTE
# 6076              80231               80231          INCIDENTE GRAVE
# 6077              80248               80248          INCIDENTE GRAVE
# 6079              80235               80235                INCIDENTE
# 6092              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja cidade terminan com a letra A
filtro= df.ocorrencia_cidade.str[-1]=='A'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 6072              80227               80227                 ACIDENTE
# 6073              80225               80225                INCIDENTE
# 6081              80240               80240                INCIDENTE
# 6083              80238               80238          INCIDENTE GRAVE
# 6087              80244               80244                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência cuja cidade ternien com caracteres MA
filtro= df.ocorrencia_cidade.str[-2:]=='MA'
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2646              80059               80059                INCIDENTE
# 2657              51347               51347                INCIDENTE
# 2857              52340               52340                 ACIDENTE
# 2967              52832               52832                 ACIDENTE
# ...

# %%
# ocorrência cuja cidade contem (em qualquer parte do conteudo) os caracteres MA
filtro= df.ocorrencia_cidade.str.contains('MA|AL')
#df.loc[filtros, ['ocorrencia_cidade','total_recomendacoes']]
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 17                39810               39810                INCIDENTE
# ...                 ...                 ...                      ...
# 6054              80205               80205                INCIDENTE
# 6065              80212               80212                INCIDENTE
# 6069              80221               80221          INCIDENTE GRAVE
# 6072              80227               80227                 ACIDENTE
# 6085              80249               80249                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência do ano 2015
filtro= df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2996              52992               52992          INCIDENTE GRAVE
# 2997              52979               52979                 ACIDENTE
# 2998              53073               53073                INCIDENTE
# 2999              53074               53074                INCIDENTE
# 3000              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrência do ano 2015 e mês 12
filtro1= df.ocorrencia_dia.dt.year == 2015
filtro2= df.ocorrencia_dia.dt.month == 12
filtro3= df.ocorrencia_dia.dt.day == 8
df.loc[filtro1 &filtro2 & filtro3] #a orden nã importa
#equivalentemente podemos fazer da forma
#filtro= (df.ocorrencia_dia.dt.year == 2015) & (df.ocorrencia_dia.dt.month == 12)
#df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629          INCIDENTE GRAVE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3436             AGUAÍ            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# 3438          CAMPINAS            SP                 SBKP     2015-12-08
# 3439     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
# ocorrência do ano 2015 e mês 12 e dias entre 03 e 08
filtro1= df.ocorrencia_dia.dt.year == 2015
filtro2= df.ocorrencia_dia.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia.dt.day >= 3 
filtro_dia_fin = df.ocorrencia_dia.dt.day <= 8
df.loc[filtro1 &filtro2 & filtro_dia_inicio & filtro_dia_fin]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629          INCIDENTE GRAVE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
#posso cria uma coluna de dia e hora juntos
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
# ocorrência do ano 2015 e mês 12 e dias entre 03 e 08
filtro1= df.ocorrencia_dia_hora.dt.year == 2015
filtro2= df.ocorrencia_dia_hora.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia_hora.dt.day >= 3 
filtro_dia_fin = df.ocorrencia_dia_hora.dt.day <= 8
df.loc[filtro1 &filtro2 & filtro_dia_inicio & filtro_dia_fin]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629          INCIDENTE GRAVE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
filtro1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = df.ocorrencia_dia_hora <= '2015-12-08 14:30:00'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629          INCIDENTE GRAVE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3433    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434          TRINDADE            GO                  NaN     2015-12-06
# 3435         AMERICANA            SP                 SDAI     2015-12-06
# 3436             AGUAÍ            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# ...

# %%
# agrupamento de dados para gerar novas informações com as já existentes
filtro1= df.ocorrencia_dia.dt.year == 2015
filtro2= df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro1 & filtro2]
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3086              53183               53183                 ACIDENTE
# 3087              53120               53120                 ACIDENTE
# 3088              53109               53109                 ACIDENTE
# 3089              53112               53112                 ACIDENTE
# 3090              53152               53152          INCIDENTE GRAVE
# 3091              53167               53167                INCIDENTE
# 3092              53596               53596                INCIDENTE
# 3093              53149               53149                 ACIDENTE
# 3094              53148               53148                 ACIDENTE
# 3095              53153               53153                INCIDENTE
# 3096              53154               53154                INCIDENTE
# 3097              53238               53238                INCIDENTE
# 3098              53189               53189                INCIDENTE
# ...

# %%
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
#ter cuidado com elementos nulos
df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
#para não ter ese problema de elementos nulos podemos  usamos size()
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#agrupando onde creciente
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
#agrupando ordem decrecente
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
filtro1= df.ocorrencia_dia.dt.year == 2010
filtro2= df.ocorrencia_uf.isin(['SP','MG','ES','RJ'])
dfsudeste2010 = df.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# ...

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
#agrupamento por estado
dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_uf','ocorrencia_classificacao']).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             INCIDENTE                    5
# MG             ACIDENTE                     7
#                INCIDENTE                   39
#                INCIDENTE GRAVE              5
# RJ             ACIDENTE                     9
#                INCIDENTE                   52
#                INCIDENTE GRAVE              4
# SP             ACIDENTE                    24
#                INCIDENTE                   74
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
#agrupamento por cidades
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# JUIZ DE FORA              4
# VITÓRIA                   4
# MARÍLIA                   3
# SÃO JOSÉ DOS CAMPOS       3
# SÃO JOSÉ DO RIO PRETO     3
# SOROCABA                  2
# ITANHAÉM                  2
# RIBEIRÃO PRETO            2
# IPATINGA                  2
# POÇOS DE CALDAS           2
# DIVINÓPOLIS               2
# BAURU                     2
# JUNDIAÍ                   2
# ARARAQUARA                2
# CAMPOS DOS GOYTACAZES     2
# AREALVA                   2
# MONTES CLAROS             2
# UBERABA                   2
# POUSO ALEGRE              1
# PIRACICABA                1
# PIRASSUNUNGA              1
# ARRAIAL DO CABO           1
# RESENDE                   1
# PENÁPOLIS                 1
# ...

# %%
filtro1 = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro2 = dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 119              40190               40190                INCIDENTE
# 274              41750               41750                 ACIDENTE
# 326              42250               42250                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 119    RIO DE JANEIRO            RJ                 SBGL     2010-04-06
# 274    RIO DE JANEIRO            RJ                 SBJR     2010-07-12
# 326    RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 119        02:35:00                    3 2010-04-06 02:35:00
# 274        19:53:00                    3 2010-07-12 19:53:00
# 326        12:26:00                   19 2010-08-12 12:26:00

# %%
filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
#total de remomendações por cidades pode ser por aerodromo tambem
#dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
dfsudeste2010.groupby(['ocorrencia_aerodromo'],dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# NaN     45
# Name: total_recomendacoes, dtype: int64

# %%
filtro =  dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# BELO HORIZONTE            2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# IPERÓ                     3
# ITANHAÉM                  1
# JUNDIAÍ                   7
# NOVO HORIZONTE            3
# RESENDE                   8
# RIO DE JANEIRO           25
# SÃO BERNARDO DO CAMPO     2
# SÃO PAULO                41
# TIMÓTEO                   3
# Name: total_recomendacoes, dtype: int64

# %%
filtro =  dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
#filtro de recomensações por meses
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# ITANHAÉM               9                  1
# SÃO PAULO              6                  2
# SÃO BERNARDO DO CAMPO  1                  2
# JUNDIAÍ                6                  2
# RIO DE JANEIRO         7                  3
#                        4                  3
# NOVO HORIZONTE         7                  3
# IPERÓ                  1                  3
# TIMÓTEO                2                  3
# JUNDIAÍ                5                  5
# SÃO PAULO              11                 6
# RESENDE                4                  8
# SÃO PAULO              1                  8
# CAMANDUCAIA            7                  9
# BRAGANÇA PAULISTA      11                 9
# SÃO PAULO              12                11
# ...

# %%
filtro1 =  dfsudeste2010.total_recomendacoes > 0 
filtro2 =  dfsudeste2010.ocorrencia_cidade == 'SÃO PAULO' 
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11               40069               40069                 ACIDENTE
# 58               39275               39275                 ACIDENTE
# 63               39992               39992                 ACIDENTE
# 219              41411               41411          INCIDENTE GRAVE
# 469              43450               43450                 ACIDENTE
# 530              43471               43471                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 11          SÃO PAULO            SP                 SBMT     2010-01-10
# 58          SÃO PAULO            SP                  NaN     2010-02-10
# 63          SÃO PAULO            SP                 SBMT     2010-02-17
# 219         SÃO PAULO            SP                 SBMT     2010-06-08
# 469         SÃO PAULO            SP                 SBMT     2010-11-04
# ...

# %%
df.to_csv('ETL_CENIPA.csv', index=False)
